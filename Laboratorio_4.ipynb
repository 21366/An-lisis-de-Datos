# %% [markdown]
# <a href="https://colab.research.google.com/github/21366/Analisis-de-Datos/blob/main/Laboratorio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Kendra Artavia Caballero**

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
import folium

# %%
from folium.plugins import MiniMap
from branca.element import Figure

# %%
popuptextO = '<b>Omar Dengo</b>' # 9.99898657589619, -84.11144271741657
popuptextB = '<b>Benjamín Núñez</b>' # 9.971118159350976, -84.12844501926364
popuptextA = '<b>Sede Interuniversitaria</b>' # 10.019945163597935, -84.1969716885812
popuptextS = '<b>Sarapiquí</b>' # 10.319234463996382, -83.92277926159056
popuptextC = '<b>Coto</b>' # 8.573514234643122, -82.87242387509622
popuptextP = '<b>Pérez Zeledón</b>' # 9.37998972535787, -83.69147128858556
popuptextL = '<b>Liberia</b>' # 10.617717737574644, -85.45125707100483
popuptextN = '<b>Nicoya</b>' # 10.134734125697987, -85.44676239042725

my_map = folium.Map(location=(9.99898657589619, -84.11144271741657))

folium.Marker(location=[9.99898657589619, -84.11144271741657], popup=popuptextO,
              icon=folium.Icon(color="blue", icon="ok-sing")).add_to(my_map)

folium.Marker(location=[9.971118159350976, -84.12844501926364], popup=popuptextB,
              icon=folium.Icon(color="green", icon="ok-sing")).add_to(my_map)

folium.Marker(location=[10.019945163597935, -84.1969716885812], popup=popuptextA,
              icon=folium.Icon(color="red", icon="ok-sing")).add_to(my_map)

folium.Marker(location=[10.319234463996382, -83.92277926159056], popup=popuptextS,
              icon=folium.Icon(color="orange", icon="ok-sing")).add_to(my_map)

folium.Marker(location=[8.573514234643122, -82.87242387509622], popup=popuptextC,
              icon=folium.Icon(color="purple", icon="ok-sing")).add_to(my_map)

folium.Marker(location=[9.37998972535787, -83.69147128858556], popup=popuptextP,
              icon=folium.Icon(color="cadetblue", icon="ok-sing")).add_to(my_map)

folium.Marker(location=[10.134734125697987, -85.44676239042725], popup=popuptextN,
              icon=folium.Icon(color="pink", icon="ok-sing")).add_to(my_map)

folium.Marker(location=[10.617717737574644, -85.45125707100485], popup=popuptextL,
              icon=folium.Icon(color="gray", icon="ok-sing")).add_to(my_map)

folium.Circle(location=[9.99898657589619, -84.11144271741657], color="blue", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Omar Dengo").add_to(my_map)

folium.Circle(location=[9.971118159350976, -84.12844501926364], color="green", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Benjamín Núñez").add_to(my_map)

folium.Circle(location=[10.019945163597935, -84.1969716885812], color="red", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Sede Interuniversitaria").add_to(my_map)

folium.Circle(location=[10.319234463996382, -83.92277926159056], color="orange", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Sarapiquí").add_to(my_map)

folium.Circle(location=[8.573514234643122, -82.87242387509622], color="purple", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Coto").add_to(my_map)

folium.Circle(location=[9.37998972535787, -83.69147128858556], color="cadetblue", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Pérez Zeledón").add_to(my_map)

folium.Circle(location=[10.134734125697987, -85.44676239042725], color="pink", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Nicoya").add_to(my_map)

folium.Circle(location=[10.617717737574644, -85.45125707100485], color="gray", weight=6,
              fill_color="red", fill_opacity=0.5, tooltip="Liberia").add_to(my_map)

minimap = MiniMap(title_layer="steamenterrain", position='bottomright')
my_map.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
